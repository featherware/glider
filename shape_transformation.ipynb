# %%
from pathlib import Path

repository_path = Path('.').resolve()

# !pip install -Uqq -r {repository_path}/requirements.txt -r {repository_path}/requirements-dev.txt

# !export PYTHONPATH=$PYTHONPATH:..:../src
# !echo $PYTHONPATH

# %%
import vehicle
from constants import DEFAULT_STL_FILEPATH

v = vehicle.Vehicle(filename=DEFAULT_STL_FILEPATH)
v.create_glider_from_vertices()
len(v.vertices)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 import vehicle
#       2 from constants import DEFAULT_STL_FILEPATH
# ----> 4 v = vehicle.Vehicle(filename=DEFAULT_STL_FILEPATH)
#       5 v.create_glider_from_vertices()
#       6 len(v.vertices)
#
# File ~/Developer/glider/vehicle.py:45, in Vehicle.__init__(self, vertices, filename, orientation, wing_density)
#      42 else:
#      43     raise ValueError("Must provide either vertices or filename")
# ---> 45 self.vertices_parameter = nn.Parameter(np.array(vertices))
#
# File ~v/.pyenv/versions/3.11.0/lib/python3.11/site-packages/torch/nn/parameter.py:39, in Parameter.__new__(cls, data, requires_grad)
#      36     return torch.Tensor._make_subclass(cls, data, requires_grad)
#      38 # Path for custom tensors: set a flag on the instance to indicate parameter-ness.
# ---> 39 t = data.detach().requires_grad_(requires_grad)
#      40 if type(t) is not type(data):
#      41     raise RuntimeError(f"Creating a Parameter from an instance of type {type(data).__name__} "
#      42                        "requires that detach() returns an instance of the same type, but return "
#      43                        f"type {type(t).__name__} was found instead. To use the type as a "
#      44                        "Parameter, please correct the detach() semantics defined by "
#      45                        "its __torch_dispatch__() implementation.")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'detach'

# %%
import torch.optim as optim

optim.Adam(model.parameters(), lr=0.001)
# Out:
# ('\n    <body name="body" pos="0 0 1" euler="0 0 0">\n        <freejoint/>\n        <!-- Main Wing -->\n        <geom name="stl-wing"  density="40" rgba="0.8 0.2 0.2 0.5" type="mesh" mesh="stl-wing-mesh"/>\n        <!-- Pilot -->\n        <geom name="pilot" type="box" size="1.8 0.3 0.6" mass="68" rgba="0.2 0.2 0.8 0.5" pos="0 0 -0.3"/>\n        <camera name="fixed" pos="-100 -100 -10" xyaxes="1 0 0 0 1 2"/>\n        <camera name="track" pos="0 0 0" xyaxes="1 2 0 0 1 2" mode="track"/>\n    </body>\n    ',
#  '\n        <asset>\n            <mesh name="stl-wing-mesh" vertex="0.0 -2.691140651702881 0.07199021428823471 0.0 -2.691140651702881 0.10471739619970322 0.011656414717435837 -2.692288875579834 0.10471739619970322 0.011656414717435837 -2.692288875579834 0.07199021428823471 0.02286488190293312 -2.6956887245178223 0.10471739619970322 0.02286488190293312 -2.6956887245178223 0.07199021428823471 0.033194661140441895 -2.7012102603912354 0.10471739619970322 0.033194661140441895 -2.7012102603912354 0.07199021428823471 0.042248789221048355 -2.7086408138275146 0.10471739619970322 0.042248789221048355 -2.7086408138275146 0.07199021428823471 0.04967932403087616 -2.7176947593688965 0.10471739619970322 0.04967932403087616 -2.7176949977874756 0.07199021428823471 0.05520069971680641 -2.72802472114563 0.10471738874912262 0.05520069971680641 -2